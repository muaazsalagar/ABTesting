# %% [markdown]
# # Introduction:  A/B testing

# %% [markdown]
# ## Steps:
#
# 1. Data
# 2. Choosing a metric
# 3. Review Stat
# 4. How to Design
# 5. How to Analyze results

# %% [markdown]
# ## Overview
#
# A process to check your product or feature?
#
# Devide into control set and experiment set and analyze which one is better.
#
#
# How users repond to your change ?
#     1. which features would work?
#     2. Diffrernt UI? Different features?
#     3. What to show on news feed?
#     4. Is there any change due to speed?
#
#
# Change Aversion:
# Ppl want their usual UI ppl are used to it.
#
# What you can't you do with A/B testing?
#
# We cant measure new experience
#
#     1. Change aversion- I liked my old way
#     2. Novelty- Ppl get excited and they test everything.
#
# In some cases time can be a constraint.
# in short time period it is hard to see exactly the effect.
#
#
# A/B test won't tell you is you are missing something.So we cant change the completeness of the service/ website
#
# Some of the examples where we can use:
# 1. Adding a new service like for premium service?
#
# 2. Page load/ delay has effect ?
#
# 3. Changing a home page etc
#
# 4. But for cases like changing if changing enrire compnay logo and brand can not be tested. As it is way too emotional for users and it is really hard to have controlled experiment with.
#
#
#
# ## History:
#
# Agriculture:
#
# Ppl started with testing what grows better with what
#
#
# Hypothesis testing, example in clinical trials.
#
# ## Challenges in Online world:
#
# We dont have low resolutio data. As we cant know all about users like thier age, thier income etc
#
# We have millions of users, millions of clicks.
#
# So in online world we have to test A/b
# Goal is is to design a robust system which will give a repeatable/ consistent result So that we can design tests and check for their effects.

# %% [markdown]
# ## Example:
#
# Lets assume we are working on Education site.
#
#
# **b Customer Funnel **
#
# The usual flow for users will be your homepage, then some services, then order, cart, etc
#
# **b Metric **
# So making a change in one of the buttons who much will be the effect?
# how many more student will go to the explore services page? due to this change?
#
#
# CTR: Click though rate
#
# CTR= Number of Clicks / Number of page views
#
#
# CTP: Click throuh probability
# CTP= unique visitors who clicked the button/ Total unique visitors to page
#
#
#
#
# Hypothesis:
# Changing the button increases our CTP.
#
#
#
# ## CTP Vs CTR
#
#
# We want to come up with correct metric we shoud choose
#
# Usablity = Rate = how often they find that page? from differnt parts/ locations of the page ? We can use metric Rate as we need to calculate
#
#
# When to use probabilty:
#
# To check if users progressing to different stage of funnel?
#
# To measure impact !!
#
#
# So dont want to check double clicks, may be due to double reload from user we dont
#
#
# So we need to change website.
# We need count page views and clicks.
#
#
# And we need to be sure that the sampled data we get is confident enough for us?

# %% [markdown]
# ## Stat :
#
# One condition is sucess and other is fail
#
# So any distribution that has similar behaviour?
#
#
# Ans: Binomial (p and i-p ?)
#
# ## Properties of the Binomial:
#
#     1. 2 types
#     2. Independent events
#     3. Identical Distribution
#         Success prbability should same.
#
#
#
#
# Example:
# A dice rolled and for event 2 or not?
